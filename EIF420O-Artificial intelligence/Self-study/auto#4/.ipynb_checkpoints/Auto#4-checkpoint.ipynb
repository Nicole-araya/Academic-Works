# %%
import random
random.seed(666)
import math

# %%
def f(x, y):
    return 2*x**2*y**2 - 6*x*y**2 + 3*y**2 - 1

def g(x, y):
    return (x - 2)**2 + 2*(y-1)**2 + x

def gradient_f(x, y):
    f_x = (4*x - 6)*y**2
    f_y = (4*x**2 - 12*x + 6)*y
    return f_x, f_y

def gradient_g(x, y):
    g_x = 2*x - 3
    g_y = 4*(y - 1)
    return g_x, g_y

# %%
def gradient_descent(gradient, 
                     critical_point, 
                     f, 
                     max_iter=100, 
                     epsilon=1e-5, 
                     initial=None, 
                     lr=0.01):
    if initial is None:
        initial = random.random(), random.random()
    actual_min = f(*critical_point)
    xn, yn = initial
    
    for iter in range(max_iter):
        grad_x, grad_y = gradient(xn, yn)
        xn, yn = (xn - lr * grad_x, yn - lr*grad_y)
        estimated_min = f(xn, yn)
        print(f"{iter=:2} aprox_{iter} = ({xn=:}, {yn=:}) {actual_min}==?{estimated_min} ")
        if abs(actual_min - estimated_min) < epsilon:
            print(f"*** Convergence achieved *** at {iter=:}")
            break

# %%
gradient_descent(gradient_g, (1.5, 1), g, max_iter=150, lr=0.05)
# Out:
# iter= 0 aprox_0 = (xn=1.0399360449949688, yn=0.21341212460342573) 1.75==?3.199099814136664 ### (grad_x=-1.022364, grad_y=-3.932939)
# iter= 1 aprox_1 = (xn=1.0859424404954718, yn=0.3707296996827406) 1.75==?2.7134058843055935 ### (grad_x=-0.920128, grad_y=-3.146352)
# iter= 2 aprox_2 = (xn=1.1273481964459247, yn=0.4965837597461925) 1.75==?2.3957251885946635 ### (grad_x=-0.828115, grad_y=-2.517081)
# iter= 3 aprox_3 = (xn=1.1646133768013323, yn=0.597267007796954) 1.75==?2.1868719130382424 ### (grad_x=-0.745304, grad_y=-2.013665)
# iter= 4 aprox_4 = (xn=1.198152039121199, yn=0.6778136062375631) 1.75==?2.048720336137978 ### (grad_x=-0.670773, grad_y=-1.610932)
# iter= 5 aprox_5 = (xn=1.228336835209079, yn=0.7422508849900505) 1.75==?1.9566700876810432 ### (grad_x=-0.603696, grad_y=-1.288746)
# iter= 6 aprox_6 = (xn=1.2555031516881712, yn=0.7938007079920404) 1.75==?1.894815004883585 ### (grad_x=-0.543326, grad_y=-1.030996)
# iter= 7 aprox_7 = (xn=1.279952836519354, yn=0.8350405663936323) 1.75==?1.8528439836273454 ### (grad_x=-0.488994, grad_y=-0.824797)
# iter= 8 aprox_8 = (xn=1.3019575528674185, yn=0.8680324531149058) 1.75==?1.8240516777280003 ### (grad_x=-0.440094, grad_y=-0.659838)
# iter= 9 aprox_9 = (xn=1.3217617975806766, yn=0.8944259624919246) 1.75==?1.8040606115931848 ### (grad_x=-0.396085, grad_y=-0.527870)
# iter=10 aprox_10 = (xn=1.3395856178226089, yn=0.9155407699935397) 1.75==?1.7899994970759225 ### (grad_x=-0.356476, grad_y=-0.422296)
# iter=11 aprox_11 = (xn=1.355627056040348, yn=0.9324326159948317) 1.75==?1.7799742497101805 ### (grad_x=-0.320829, grad_y=-0.337837)
# iter=12 aprox_12 = (xn=1.3700643504363132, yn=0.9459460927958654) 1.75==?1.7727269227956035 ### (grad_x=-0.288746, grad_y=-0.270270)
# iter=13 aprox_13 = (xn=1.3830579153926819, yn=0.9567568742366923) 1.75==?1.7674153870038678 ### (grad_x=-0.259871, grad_y=-0.216216)
# iter=14 aprox_14 = (xn=1.3947521238534137, yn=0.9654054993893538) 1.75==?1.7634706743783672 ### (grad_x=-0.233884, grad_y=-0.172973)
# iter=15 aprox_15 = (xn=1.4052769114680723, yn=0.9723243995114831) 1.75==?1.7605043412258274 ### (grad_x=-0.210496, grad_y=-0.138378)
# iter=16 aprox_16 = (xn=1.414749220321265, yn=0.9778595196091865) 1.75==?1.7582480971797043 ### (grad_x=-0.189446, grad_y=-0.110702)
# iter=17 aprox_17 = (xn=1.4232742982891384, yn=0.9822876156873492) 1.75==?1.7565142904191022 ### (grad_x=-0.170502, grad_y=-0.088562)
# iter=18 aprox_18 = (xn=1.4309468684602247, yn=0.9858300925498794) 1.75==?1.7551699075297396 ### (grad_x=-0.153451, grad_y=-0.070850)
# iter=19 aprox_19 = (xn=1.4378521816142023, yn=0.9886640740399035) 1.75==?1.7541193577648597 ### (grad_x=-0.138106, grad_y=-0.056680)
# iter=20 aprox_20 = (xn=1.444066963452782, yn=0.9909312592319228) 1.75==?1.7532929886956297 ### (grad_x=-0.124296, grad_y=-0.045344)
# iter=21 aprox_21 = (xn=1.4496602671075038, yn=0.9927450073855383) 1.75==?1.7526393585433597 ### (grad_x=-0.111866, grad_y=-0.036275)
# iter=22 aprox_22 = (xn=1.4546942403967535, yn=0.9941960059084306) 1.75==?1.752119984548057 ### (grad_x=-0.100679, grad_y=-0.029020)
# iter=23 aprox_23 = (xn=1.4592248163570782, yn=0.9953568047267445) 1.75==?1.751705734125805 ### (grad_x=-0.090612, grad_y=-0.023216)
# iter=24 aprox_24 = (xn=1.4633023347213705, yn=0.9962854437813956) 1.75==?1.7513743144927048 ### (grad_x=-0.081550, grad_y=-0.018573)
# iter=25 aprox_25 = (xn=1.4669721012492334, yn=0.9970283550251164) 1.75==?1.7511085034436045 ### (grad_x=-0.073395, grad_y=-0.014858)
# iter=26 aprox_26 = (xn=1.47027489112431, yn=0.9976226840200931) 1.75==?1.7508948853602082 ### (grad_x=-0.066056, grad_y=-0.011887)
# iter=27 aprox_27 = (xn=1.473247402011879, yn=0.9980981472160745) 1.75==?1.7507229355871374 ### (grad_x=-0.059450, grad_y=-0.009509)
# iter=28 aprox_28 = (xn=1.475922661810691, yn=0.9984785177728596) 1.75==?1.7505843480306174 ### (grad_x=-0.053505, grad_y=-0.007607)
# iter=29 aprox_29 = (xn=1.478330395629622, yn=0.9987828142182876) 1.75==?1.750472534836023 ### (grad_x=-0.048155, grad_y=-0.006086)
# iter=30 aprox_30 = (xn=1.4804973560666599, yn=0.9990262513746301) 1.75==?1.7503822494931613 ### (grad_x=-0.043339, grad_y=-0.004869)
# iter=31 aprox_31 = (xn=1.482447620459994, yn=0.999221001099704) 1.75==?1.7503092997060898 ### (grad_x=-0.039005, grad_y=-0.003895)
# iter=32 aprox_32 = (xn=1.4842028584139946, yn=0.9993768008797632) 1.75==?1.7502503264365752 ### (grad_x=-0.035105, grad_y=-0.003116)
# iter=33 aprox_33 = (xn=1.485782572572595, yn=0.9995014407038105) 1.75==?1.7502026323653972 ### (grad_x=-0.031594, grad_y=-0.002493)
# iter=34 aprox_34 = (xn=1.4872043153153356, yn=0.9996011525630484) 1.75==?1.7501640477051053 ### (grad_x=-0.028435, grad_y=-0.001994)
# iter=35 aprox_35 = (xn=1.4884838837838021, yn=0.9996809220504387) 1.75==?1.7501328245541807 ### (grad_x=-0.025591, grad_y=-0.001595)
# iter=36 aprox_36 = (xn=1.4896354954054218, yn=0.999744737640351) 1.75==?1.7501075532732355 ### (grad_x=-0.023032, grad_y=-0.001276)
# iter=37 aprox_37 = (xn=1.4906719458648796, yn=0.9997957901122808) 1.75==?1.7500870959973043 ### (grad_x=-0.020729, grad_y=-0.001021)
# iter=38 aprox_38 = (xn=1.4916047512783916, yn=0.9998366320898247) 1.75==?1.7500705335792457 ### (grad_x=-0.018656, grad_y=-0.000817)
# iter=39 aprox_39 = (xn=1.4924442761505525, yn=0.9998693056718597) 1.75==?1.750057123124904 ### (grad_x=-0.016790, grad_y=-0.000653)
# iter=40 aprox_40 = (xn=1.4931998485354974, yn=0.9998954445374878) 1.75==?1.7500462639236296 ### (grad_x=-0.015111, grad_y=-0.000523)
# iter=41 aprox_41 = (xn=1.4938798636819477, yn=0.9999163556299903) 1.75==?1.7500374700613128 ### (grad_x=-0.013600, grad_y=-0.000418)
# iter=42 aprox_42 = (xn=1.494491877313753, yn=0.9999330845039922) 1.75==?1.750030348370894 ### (grad_x=-0.012240, grad_y=-0.000335)
# iter=43 aprox_43 = (xn=1.4950426895823776, yn=0.9999464676031937) 1.75==?1.7500245806580117 ### (grad_x=-0.011016, grad_y=-0.000268)
# iter=44 aprox_44 = (xn=1.4955384206241398, yn=0.999957174082555) 1.75==?1.7500199093586455 ### (grad_x=-0.009915, grad_y=-0.000214)
# iter=45 aprox_45 = (xn=1.4959845785617258, yn=0.999965739266044) 1.75==?1.7500161259569227 ### (grad_x=-0.008923, grad_y=-0.000171)
# iter=46 aprox_46 = (xn=1.4963861207055533, yn=0.9999725914128352) 1.75==?1.750013061626016 ### (grad_x=-0.008031, grad_y=-0.000137)
# iter=47 aprox_47 = (xn=1.496747508634998, yn=0.9999780731302682) 1.75==?1.7500105796616547 ### (grad_x=-0.007228, grad_y=-0.000110)
# iter=48 aprox_48 = (xn=1.4970727577714982, yn=0.9999824585042145) 1.75==?1.7500085693624725 ### (grad_x=-0.006505, grad_y=-0.000088)
# *** Convergence achieved *** at iter=48
