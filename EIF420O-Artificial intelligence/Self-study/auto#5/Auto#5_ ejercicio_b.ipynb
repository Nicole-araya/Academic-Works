# %%
import random
random.seed(666)
import math

# %%
def f(x, y):
    return (x - 1/2)**2 + (y - 1/4)**2 + 3

# %%
def gradient_f(x, y):
    f_x = 2 * (x - 1/2)
    f_y = 2 * (y - 1/4)
    return f_x, f_y

# %%
def gradient_descent(gradient, 
                     critical_point, 
                     f, 
                     max_iter=100, 
                     epsilon=1e-5, 
                     initial=None, 
                     lr=0.01):
    if initial is None:
        initial = random.random(), random.random()
    actual_min = f(*critical_point)
    xn, yn = initial
    for iter in range(max_iter):
        grad_x, grad_y = gradient(xn, yn)
        xn, yn = (xn - lr * grad_x, yn - lr * grad_y)
        estimated_min = f(xn, yn)
        print(f"{iter=:2} aprox_{iter} = ({xn=:}, {yn=:}) {actual_min}==?{estimated_min} ")
        if abs(actual_min - estimated_min) < epsilon:
            print(f"*** Convergence achieved *** at {iter=:}")
            break

# %%
gradient_descent(gradient_f, (1/2, 1/4), f, max_iter=150, lr=0.05)
# Out:
# iter= 0 aprox_0 = (xn=0.44093794714770984, yn=0.47556402171254697) 3.0==?3.0543674539782653
# iter= 1 aprox_1 = (xn=0.44684415243293885, yn=0.45300761954129226) 3.0==?3.0440376377223948
# iter= 2 aprox_2 = (xn=0.452159737189645, yn=0.43270685758716304) 3.0==?3.03567048655514
# iter= 3 aprox_3 = (xn=0.4569437634706805, yn=0.4144361718284467) 3.0==?3.0288930941096632
# iter= 4 aprox_4 = (xn=0.46124938712361246, yn=0.39799255464560207) 3.0==?3.023403406228827
# iter= 5 aprox_5 = (xn=0.4651244484112512, yn=0.38319329918104184) 3.0==?3.01895675904535
# iter= 6 aprox_6 = (xn=0.4686120035701261, yn=0.36987396926293764) 3.0==?3.0153549748267334
# iter= 7 aprox_7 = (xn=0.4717508032131135, yn=0.3578865723366439) 3.0==?3.012437529609654
# iter= 8 aprox_8 = (xn=0.47457572289180217, yn=0.3470979151029795) 3.0==?3.0100743989838197
# iter= 9 aprox_9 = (xn=0.47711815060262197, yn=0.33738812359268155) 3.0==?3.0081602631768942
# iter=10 aprox_10 = (xn=0.4794063355423598, yn=0.3286493112334134) 3.0==?3.0066098131732844
# iter=11 aprox_11 = (xn=0.48146570198812383, yn=0.32078438011007204) 3.0==?3.00535394867036
# iter=12 aprox_12 = (xn=0.48331913178931146, yn=0.3137059420990648) 3.0==?3.004336698422992
# iter=13 aprox_13 = (xn=0.4849872186103803, yn=0.30733534788915834) 3.0==?3.0035127257226235
# iter=14 aprox_14 = (xn=0.48648849674934225, yn=0.3016018131002425) 3.0==?3.002845307835325
# iter=15 aprox_15 = (xn=0.487839647074408, yn=0.2964416317902182) 3.0==?3.002304699346613
# iter=16 aprox_16 = (xn=0.4890556823669672, yn=0.2917974686111964) 3.0==?3.0018668064707565
# iter=17 aprox_17 = (xn=0.4901501141302705, yn=0.2876177217500767) 3.0==?3.0015121132413127
# iter=18 aprox_18 = (xn=0.4911351027172434, yn=0.28385594957506904) 3.0==?3.0012248117254634
# iter=19 aprox_19 = (xn=0.4920215924455191, yn=0.28047035461756215) 3.0==?3.000992097497625
# iter=20 aprox_20 = (xn=0.49281943320096716, yn=0.2774233191558059) 3.0==?3.0008035989730764
# iter=21 aprox_21 = (xn=0.49353748988087043, yn=0.2746809872402253) 3.0==?3.000650915168192
# iter=22 aprox_22 = (xn=0.4941837408927834, yn=0.2722128885162028) 3.0==?3.0005272412862354
# iter=23 aprox_23 = (xn=0.494765366803505, yn=0.2699915996645825) 3.0==?3.000427065441851
# iter=24 aprox_24 = (xn=0.4952888301231545, yn=0.26799243969812425) 3.0==?3.0003459230078993
# iter=25 aprox_25 = (xn=0.49575994711083904, yn=0.26619319572831185) 3.0==?3.0002801976363984
# iter=26 aprox_26 = (xn=0.49618395239975516, yn=0.26457387615548067) 3.0==?3.0002269600854827
# iter=27 aprox_27 = (xn=0.4965655571597796, yn=0.2631164885399326) 3.0==?3.000183837669241
# iter=28 aprox_28 = (xn=0.4969090014438017, yn=0.2618048396859393) 3.0==?3.000148908512085
# iter=29 aprox_29 = (xn=0.4972181012994215, yn=0.2606243557173454) 3.0==?3.000120615894789
# iter=30 aprox_30 = (xn=0.49749629116947935, yn=0.25956192014561086) 3.0==?3.000097698874779
# iter=31 aprox_31 = (xn=0.49774666205253143, yn=0.25860572813104976) 3.0==?3.000079136088571
# iter=32 aprox_32 = (xn=0.4979719958472783, yn=0.2577451553179448) 3.0==?3.0000641002317425
# iter=33 aprox_33 = (xn=0.49817479626255046, yn=0.2569706397861503) 3.0==?3.0000519211877115
# iter=34 aprox_34 = (xn=0.4983573166362954, yn=0.2562735758075353) 3.0==?3.0000420561620462
# iter=35 aprox_35 = (xn=0.49852158497266585, yn=0.25564621822678174) 3.0==?3.0000340654912576
# iter=36 aprox_36 = (xn=0.49866942647539925, yn=0.25508159640410355) 3.0==?3.0000275930479186
# iter=37 aprox_37 = (xn=0.4988024838278593, yn=0.2545734367636932) 3.0==?3.000022350368814
# iter=38 aprox_38 = (xn=0.49892223544507336, yn=0.25411609308732386) 3.0==?3.0000181037987392
# iter=39 aprox_39 = (xn=0.499030011900566, yn=0.25370448377859145) 3.0==?3.000014664076979
# iter=40 aprox_40 = (xn=0.4991270107105094, yn=0.2533340354007323) 3.0==?3.000011877902353
# iter=41 aprox_41 = (xn=0.49921430963945845, yn=0.2530006318606591) 3.0==?3.0000096211009057
# *** Convergence achieved *** at iter=41
